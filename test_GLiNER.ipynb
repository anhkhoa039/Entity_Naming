# %%
model = GLiNER.from_pretrained("knowledgator/gliner-multitask-large-v0.5")
# Out:
# Fetching 10 files:   0%|          | 0/10 [00:00<?, ?it/s]
# pytorch_model.bin:   0%|          | 0.00/1.76G [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# gliner_config.json: 0.00B [00:00, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/286 [00:00<?, ?B/s]
# gliner_multitask_performance.png:   0%|          | 0.00/76.8k [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/86.0 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]

# %%
labels_bank = [
    "Person",
    "Organization",
    "Location",
    "Product",
    "Event",
    "Facility",
    "Work Of Art",
    "Law",
    "Document",
    "Software",
    "Dataset",
    "Metric",
    "Disease",
    "Chemical",
    "Biological Entity",
    "Financial Instrument",
]

# %%
from gliner import GLiNER

# Initialize GLiNER with the base model
model = GLiNER.from_pretrained("knowledgator/gliner-multitask-large-v0.5")

# Sample text for entity prediction
text = """
Cristiano Ronaldo dos Santos Aveiro (Portuguese pronunciation: [kɾiʃˈtjɐnu ʁɔˈnaldu]; born 5 February 1985) is a Portuguese professional footballer who plays as a forward for and captains both Saudi Pro League club Al Nassr and the Portugal national team. Widely regarded as one of the greatest players of all time, Ronaldo has won five Ballon d'Or awards,[note 3] a record three UEFA Men's Player of the Year Awards, and four European Golden Shoes, the most by a European player. He has won 33 trophies in his career, including seven league titles, five UEFA Champions Leagues, the UEFA European Championship and the UEFA Nations League. Ronaldo holds the records for most appearances (183), goals (140) and assists (42) in the Champions League, goals in the European Championship (14), international goals (128) and international appearances (205). He is one of the few players to have made over 1,200 professional career appearances, the most by an outfield player, and has scored over 850 official senior career goals for club and country, making him the top goalscorer of all time.
"""

# Labels for entity prediction
# Most GLiNER models should work best when entity types are in lower case or title case
labels = ["Person", "Award", "Date", "Competitions", "Teams"]

# Perform entity prediction
entities = model.predict_entities(text, labels, threshold=0.5)

# Display predicted entities and their labels
for entity in entities:
    print(entity["text"], "=>", entity["label"])
# Out:
# Fetching 10 files:   0%|          | 0/10 [00:00<?, ?it/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Cristiano Ronaldo dos Santos Aveiro => Person
# 5 February 1985 => Date
# Al Nassr => Teams
# Portugal national team => Teams
# UEFA Men's Player of the Year Awards => Award
# European Golden Shoes => Award
# UEFA Champions Leagues => Competitions
# UEFA European Championship => Competitions
# UEFA Nations League => Competitions

# %%
# Perform entity prediction
entities = model.predict_entities(text, labels_bank, threshold=0.5)

# Display predicted entities and their labels
for entity in entities:
    print(entity["text"], "=>", entity["label"])
# Out:
# Cristiano Ronaldo dos Santos Aveiro => Person
# Al Nassr => Organization
# Portugal national team => Organization
# UEFA Champions Leagues => Event
# UEFA European Championship => Event
# UEFA Nations League => Event

# %%
import torch
torch.__version__
# Out:
# '2.1.0+cu121'

# %%
test_data = {
        "str_words": [
            "Parties",
            "with",
            "mainly",
            "Eurosceptic",
            "views",
            "are",
            "Serbian",
            "Radical",
            "Party",
            ",",
            "Democratic",
            "Party",
            "of",
            "Serbia",
            ",",
            "Dveri",
            ",",
            "DJB",
            "and",
            "the",
            "Serbian",
            "People",
            "'s",
            "Party",
            "of",
            "Nenad",
            "Popović",
            "."
        ],
        "tags_ner": [
            "O",
            "O",
            "O",
            "O",
            "O",
            "O",
            "B-politicalparty",
            "I-politicalparty",
            "I-politicalparty",
            "O",
            "B-politicalparty",
            "I-politicalparty",
            "I-politicalparty",
            "I-politicalparty",
            "O",
            "B-politicalparty",
            "O",
            "B-politicalparty",
            "O",
            "O",
            "B-politicalparty",
            "I-politicalparty",
            "I-politicalparty",
            "I-politicalparty",
            "O",
            "B-politician",
            "I-politician",
            "O"
        ],
        "tags_esi": [
            "O",
            "O",
            "O",
            "O",
            "O",
            "O",
            "B",
            "I",
            "I",
            "O",
            "B",
            "I",
            "I",
            "I",
            "O",
            "B",
            "O",
            "B",
            "O",
            "O",
            "B",
            "I",
            "I",
            "I",
            "O",
            "B",
            "I",
            "O"
        ],
        "tags_net": [
            "O",
            "O",
            "O",
            "O",
            "O",
            "O",
            "politicalparty",
            "politicalparty",
            "politicalparty",
            "O",
            "politicalparty",
            "politicalparty",
            "politicalparty",
            "politicalparty",
            "O",
            "politicalparty",
            "O",
            "politicalparty",
            "O",
            "O",
            "politicalparty",
            "politicalparty",
            "politicalparty",
            "politicalparty",
            "O",
            "politician",
            "politician",
            "O"
        ],
        "id": 1
    }

# %%
sent = " ".join(i for i in test_data["str_words"])

sent
# Out:
# "Parties with mainly Eurosceptic views are Serbian Radical Party , Democratic Party of Serbia , Dveri , DJB and the Serbian People 's Party of Nenad Popović ."

# %%
# Most GLiNER models should work best when entity types are in lower case or title case
# Perform entity prediction
entities = model.predict_entities(sent, labels_bank, threshold=0.3)

# Display predicted entities and their labels
for entity in entities:
    print(entity["text"], "=>", entity["label"])
# Out:
# Serbian Radical Party => Organization
# Democratic Party of Serbia => Organization
# Dveri => Organization
# DJB => Organization
# Serbian People 's Party => Organization
# Nenad Popović => Person
